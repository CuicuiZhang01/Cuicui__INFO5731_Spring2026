# %% [markdown]
# <a href="https://colab.research.google.com/github/CuicuiZhang01/Cuicui__INFO5731_Spring2026/blob/main/In_class_exercises_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In-Class Assignment — Week 2 (Lesson 2)**
#
# Time: 20–30 minutes
# Points: 10
#
# **Instructions**
#
# This is an individual in-class assignment.
#
# Complete it during class time.
#
# You may use Week 2 lecture notes / demo notebooks.
#
# Write your code under each question and print the output.
#
# Submit the GitHub link.

# %% [markdown]
# ## Question 1 ( 2 point)
# Write a Python program that  prompts the user to input the length and width of a rectangle, and then calculates and displays the area of the rectangle.

# %%
# write your answer here
# Prompt the user for the length and width
length = float(input("Enter the length: "))
width = float(input("Enter the width: "))

# Calculate the area
area = length * width

# Display the result
print(f"The area of the rectangle is: {area}")
# Out:
# Enter the length: 2
# Enter the width: 5
# The area of the rectangle is: 10.0

# %% [markdown]
# ## Question 2 ( 2 point)
# Create a Python program that interactively takes two numerical inputs from the user and swaps their values without utilizing an extra variable.

# %%
# write your answer here
# Take two numerical inputs from the user
a = float(input("Enter 1st number: "))
b = float(input("Enter 2nd number: "))

# Swap the values without using an extra variable
a, b = b, a

# Display the swapped values
print("After swapping:")
print("The 1st number:", a)
print("The 2nd number:", b)
# Out:
# Enter 1st number: 1.2
# Enter 2nd number: 3.5
# After swapping:
# The 1st number: 3.5
# The 2nd number: 1.2

# %% [markdown]
# ## Question 3 ( 2 point)
# Write a Python script to determine and print the length of a user-input string.

# %%
# write your answer here
# Prompt the user to enter a string
user_input = input("Enter a string: ")

# Determine the length of the string
length = len(user_input)

# Print the result
print("The length of the string is:", length)
# Out:
# Enter a string: Mean green
# The length of the string is: 10

# %% [markdown]
# ## Question 4 ( 2 point)
# Design a Python function to check if a number is prime.

# %%
# write your answer here
def is_prime(n):
    if n <= 1:
        return False

    # Check divisibility from 2 up to the square root of n
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False

    return True

num = int(input("Enter a number: "))

if is_prime(num):
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")
# Out:
# Enter a number: 17
# 17 is a prime number.

# %% [markdown]
# ## Question 5 ( 2 point)
# Write a Python program to concatenate following dictionaries to create a new one.
#
# Sample Dictionary : dic1={1:10, 2:20}, dic2={3:30, 4:40}, dic3={5:50,6:60},
#
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
# write your answer here
dic1 = {1: 10, 2: 20}
dic2 = {3: 30, 4: 40}
dic3 = {5: 50, 6: 60}

# Concatenate dictionaries
result = {}
result.update(dic1)
result.update(dic2)
result.update(dic3)

# Print the result
print(result)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
