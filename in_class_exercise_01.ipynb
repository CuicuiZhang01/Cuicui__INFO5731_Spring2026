# %% [markdown]
# <a href="https://colab.research.google.com/github/CuicuiZhang01/Cuicui__INFO5731_Spring2026/blob/main/in_class_exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first python code for NLP

# %%
# !pip install -U tensorflow==2.19.0 tensorflow-text==2.19.0
